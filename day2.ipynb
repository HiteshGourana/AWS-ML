# %% [markdown]
# <a href="https://colab.research.google.com/github/HiteshGourana/AWS-ML/blob/main/day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/HiteshGourana/AWS-ML/main/file.csv"

df = pd.read_csv(url)

print(df.head())
# Out:
#        name gender
# 0    nikhil   male
# 1       raj   male
# 2  devendra   male
# 3     hello   male

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/HiteshGourana/AWS-ML/main/file.xlsx"

df = pd.read_excel(url)

print(df.head())
# Out:
#        name gender
# 0    nikhil   male
# 1       raj   male
# 2  devendra   male
# 3     hello   male

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/HiteshGourana/AWS-ML/main/data.json"

df = pd.read_json(url)

print(df.head())
# Out:
#        name  age
# 0    nikhil   10
# 1  devendra   20
# 2       raj   30
# 3     hello   40
